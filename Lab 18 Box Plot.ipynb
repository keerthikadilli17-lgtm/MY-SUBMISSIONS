# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Box Plots**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will focus on the visualization of data. The dataset will be provided through an RDBMS, and you will need to use SQL queries to extract the required data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize data composition and comparisons using box plots.

# %% [markdown]
# ### Setup: Connecting to the Database

# %% [markdown]
# #### 1. Download the Database File

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite
# Out:
# --2026-07-21 15:20:32--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 211415040 (202M) [application/octet-stream]
# Saving to: ‘survey-results-public.sqlite’
#
# survey-results-publ 100%[===================>] 201.62M  39.3MB/s    in 5.2s
#
# 2026-07-21 15:20:40 (38.7 MB/s) - ‘survey-results-public.sqlite’ saved [211415040/211415040]

# %% [markdown]
# #### 2. Connect to the Database

# %% [markdown]
# **Install the needed libraries**

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=9 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Connect to the SQLite database
conn = sqlite3.connect('survey-results-public.sqlite')

# %% [markdown]
# ## Demo: Basic SQL Queries

# %% [markdown]
# #### Demo 1: Count the Number of Rows in the Table

# %%
QUERY = "SELECT COUNT(*) FROM main"
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    COUNT(*)
# 0     65437

# %% [markdown]
# #### Demo 2: List All Tables

# %%
QUERY = """
SELECT name as Table_Name 
FROM sqlite_master 
WHERE type = 'table'
"""
pd.read_sql_query(QUERY, conn)
# Out:
#   Table_Name
# 0       main

# %% [markdown]
# #### Demo 3: Group Data by Age

# %%
QUERY = """
SELECT Age, COUNT(*) as count 
FROM main 
GROUP BY Age 
ORDER BY Age
"""
df_age = pd.read_sql_query(QUERY, conn)

print(df_age)
# Out:
#                   Age  count
# 0     18-24 years old  14098
# 1     25-34 years old  23911
# 2     35-44 years old  14942
# 3     45-54 years old   6249
# 4     55-64 years old   2575
# 5   65 years or older    772
# 6   Prefer not to say    322
# 7  Under 18 years old   2568

# %% [markdown]
# ## Visualizing Data

# %% [markdown]
# ### Task 1: Visualizing the Distribution of Data

# %% [markdown]
# **1. Box Plot of `CompTotal` (Total Compensation)**

# %% [markdown]
# Use a box plot to analyze the distribution and outliers in total compensation.

# %%
# your code goes here
QUERY = "SELECT CompTotal FROM main"
df = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(8,5))
plt.boxplot(df["CompTotal"].dropna())

plt.title("Box Plot of Total Compensation")
plt.ylabel("CompTotal")

plt.show()

# %% [markdown]
# **2. Box Plot of Age (converted to numeric values)**

# %% [markdown]
# Convert the `Age` column into numerical values and visualize the distribution.

# %%
# your code goes here
QUERY = "SELECT Age FROM main"
df = pd.read_sql_query(QUERY, conn)

age_map = {
    "Under 18 years old": 17,
    "18-24 years old": 21,
    "25-34 years old": 29.5,
    "35-44 years old": 39.5,
    "45-54 years old": 49.5,
    "55-64 years old": 59.5,
    "65 years or older": 70,
    "Prefer not to say": 0
}

df["Age_Num"] = df["Age"].map(age_map)

plt.figure(figsize=(8,5))
plt.boxplot(df["Age_Num"].dropna())

plt.title("Box Plot of Age")
plt.ylabel("Age")

plt.show()

# %% [markdown]
# ### Task 2: Visualizing Relationships in Data

# %% [markdown]
# **1. Box Plot of `CompTotal` Grouped by Age Groups:**

# %% [markdown]
# Visualize the distribution of compensation across different age groups.

# %%
# your code goes here
QUERY = "SELECT Age, CompTotal FROM main"
df = pd.read_sql_query(QUERY, conn)

df.boxplot(column="CompTotal", by="Age", figsize=(10,6), rot=45)

plt.title("CompTotal by Age Group")
plt.suptitle("")
plt.xlabel("Age Group")
plt.ylabel("CompTotal")

plt.show()

# %% [markdown]
# **2. Box Plot of `CompTotal` Grouped by Job Satisfaction (`JobSatPoints_6`):**

# %% [markdown]
# Examine how compensation varies based on job satisfaction levels.

# %%
# your code goes here
QUERY = "SELECT JobSatPoints_6, CompTotal FROM main"
df = pd.read_sql_query(QUERY, conn)

df.boxplot(column="CompTotal", by="JobSatPoints_6", figsize=(10,6))

plt.title("CompTotal by Job Satisfaction")
plt.suptitle("")
plt.xlabel("Job Satisfaction")
plt.ylabel("CompTotal")

plt.show()

# %% [markdown]
# ### Task 3: Visualizing the Composition of Data

# %% [markdown]
# **1. Box Plot of `ConvertedCompYearly` for the Top 5 Developer Types:**

# %% [markdown]
# Analyze compensation across the top 5 developer roles.

# %%
# your code goes here
QUERY = "SELECT DevType, ConvertedCompYearly FROM main"
df = pd.read_sql_query(QUERY, conn)

top5 = df["DevType"].value_counts().head(5).index
df = df[df["DevType"].isin(top5)]

df.boxplot(column="ConvertedCompYearly", by="DevType", figsize=(12,6), rot=45)

plt.title("ConvertedCompYearly for Top 5 Developer Types")
plt.suptitle("")
plt.xlabel("Developer Type")
plt.ylabel("ConvertedCompYearly")

plt.show()

# %% [markdown]
# **2. Box Plot of `CompTotal` for the Top 5 Countries:**

# %% [markdown]
# Analyze compensation across respondents from the top 5 countries.

# %%
# your code goes here
QUERY = "SELECT Country, CompTotal FROM main"
df = pd.read_sql_query(QUERY, conn)

top5 = df["Country"].value_counts().head(5).index
df = df[df["Country"].isin(top5)]

df.boxplot(column="CompTotal", by="Country", figsize=(12,6), rot=45)

plt.title("CompTotal for Top 5 Countries")
plt.suptitle("")
plt.xlabel("Country")
plt.ylabel("CompTotal")

plt.show()

# %% [markdown]
# ### Task 4: Visualizing Comparison of Data

# %% [markdown]
# **1. Box Plot of CompTotal Across Employment Types:**

# %% [markdown]
# Analyze compensation for different employment types.

# %%
# your code goes here
QUERY = "SELECT Employment, CompTotal FROM main"
df = pd.read_sql_query(QUERY, conn)

df.boxplot(column="CompTotal", by="Employment", figsize=(12,6), rot=45)

plt.title("CompTotal Across Employment Types")
plt.suptitle("")
plt.xlabel("Employment Type")
plt.ylabel("CompTotal")

plt.show()

# %% [markdown]
# **2. Box Plot of `YearsCodePro` by Job Satisfaction (`JobSatPoints_6`):**

# %% [markdown]
# Examine the distribution of professional coding years by job satisfaction levels.

# %%
QUERY = "SELECT YearsCodePro, JobSatPoints_6 FROM main"

df = pd.read_sql_query(QUERY, conn)

df.boxplot(
    column="YearsCodePro",
    by="JobSatPoints_6",
    figsize=(10,6)
)

plt.title("YearsCodePro by Job Satisfaction")
plt.suptitle("")
plt.xlabel("Job Satisfaction")
plt.ylabel("YearsCodePro")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 QUERY = "SELECT YearsCodePro, JobSatPoints_6 FROM main"
#       3 df = pd.read_sql_query(QUERY, conn)
# ----> 5 df.boxplot(
#       6     column="YearsCodePro",
#       7     by="JobSatPoints_6",
#       8     figsize=(10,6)
#       9 )
#      11 plt.title("YearsCodePro by Job Satisfaction")
#      12 plt.suptitle("")
#
# File /opt/conda/lib/python3.12/site-packages/pandas/plotting/_core.py:653, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     481 """
#     482 Make a box plot from DataFrame columns.
#     483
#    (...)
#     649     <class 'numpy.ndarray'>
#     650 """
#     652 plot_backend = _get_plot_backend(backend)
# --> 653 return plot_backend.boxplot_frame(
#     654     self,
#     655     column=column,
#     656     by=by,
#     657     ax=ax,
#     658     fontsize=fontsize,
#     659     rot=rot,
#     660     grid=grid,
#     661     figsize=figsize,
#     662     layout=layout,
#     663     return_type=return_type,
#     664     **kwargs,
#     665 )
#
# File /opt/conda/lib/python3.12/site-packages/pandas/plotting/_matplotlib/boxplot.py:490, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     475 def boxplot_frame(
#     476     self,
#     477     column=None,
#    (...)
#     486     **kwds,
#     487 ):
#     488     import matplotlib.pyplot as plt
# --> 490     ax = boxplot(
#     491         self,
#     492         column=column,
#     493         by=by,
#     494         ax=ax,
#     495         fontsize=fontsize,
#     496         grid=grid,
#     497         rot=rot,
#     498         figsize=figsize,
#     499         layout=layout,
#     500         return_type=return_type,
#     501         **kwds,
#     502     )
#     503     plt.draw_if_interactive()
#     504     return ax
#
# File /opt/conda/lib/python3.12/site-packages/pandas/plotting/_matplotlib/boxplot.py:436, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     431     columns = [column]
#     433 if by is not None:
#     434     # Prefer array return type for 2-D plots to match the subplot layout
#     435     # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 436     result = _grouped_plot_by_column(
#     437         plot_group,
#     438         data,
#     439         columns=columns,
#     440         by=by,
#     441         grid=grid,
#     442         figsize=figsize,
#     443         ax=ax,
#     444         layout=layout,
#     445         return_type=return_type,
#     446         **kwds,
#     447     )
#     448 else:
#     449     if return_type is None:
#
# File /opt/conda/lib/python3.12/site-packages/pandas/plotting/_matplotlib/boxplot.py:327, in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     325 gp_col = grouped[col]
#     326 keys, values = zip(*gp_col, strict=True)
# --> 327 re_plotf = plotf(keys, values, ax, xlabel=xlabel, ylabel=ylabel, **kwargs)
#     328 ax.set_title(col)
#     329 ax_values.append(re_plotf)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/plotting/_matplotlib/boxplot.py:407, in boxplot.<locals>.plot_group(keys, values, ax, **kwds)
#     405 keys = [pprint_thing(x) for x in keys]
#     406 values = [remove_na_arraylike(v) for v in values]
# --> 407 bp = ax.boxplot(values, **kwds)
#     408 if fontsize is not None:
#     409     ax.tick_params(axis="both", labelsize=fontsize)
#
#     [... skipping hidden 2 frame]
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4541, in Axes.boxplot(self, x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label)
#    4538 whis = mpl._val_or_rc(whis, 'boxplot.whiskers')
#    4539 bootstrap = mpl._val_or_rc(bootstrap, 'boxplot.bootstrap')
# -> 4541 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    4542                                labels=tick_labels, autorange=autorange)
#    4543 notch = mpl._val_or_rc(notch, 'boxplot.notch')
#    4544 patch_artist = mpl._val_or_rc(patch_artist, 'boxplot.patchartist')
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/cbook.py:1304, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1301 x = x.data[~x.mask].ravel()
#    1303 # arithmetic mean
# -> 1304 stats['mean'] = np.mean(x)
#    1306 # medians and quartiles
#    1307 q1, med, q3 = np.percentile(x, [25, 50, 75])
#
# File /opt/conda/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3862, in mean(a, axis, dtype, out, keepdims, where)
#    3859     else:
#    3860         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3862 return _methods._mean(a, axis=axis, dtype=dtype,
#    3863                       out=out, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/numpy/_core/_methods.py:144, in _mean(a, axis, dtype, out, keepdims, where)
#     142         ret = ret.dtype.type(ret / rcount)
#     143 else:
# --> 144     ret = ret / rcount
#     146 return ret
#
# TypeError: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# ### Final Step: Close the Database Connection

# %% [markdown]
# After completing the lab, close the connection to the SQLite database:

# %%
conn.close()

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you used box plots to visualize various aspects of the dataset, focusing on:
#
# - Visualize distributions of compensation and age.
#
# - Explore relationships between compensation, job satisfaction, and professional coding experience.
#
# - Analyze data composition across developer roles and countries.
#
# - Compare compensation across employment types and satisfaction levels.
#
# Box plots provided clear insights into the spread, outliers, and central tendencies of various features in the dataset.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
